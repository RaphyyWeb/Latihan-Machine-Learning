# %%
# menghitung jumlah detik dalam sehari
jumlah_detik = 24 * 60 * 60
print(jumlah_detik)
# Out:
# 86400

# %%
# menghitung rumus persegi panjang
panjang = 10
lebar = 5
luas = panjang * lebar
print(luas)
# Out:
# 50

# %%
nama_mhs1 = "Asep"
nama_mhs2 = "Budi"
print(nama_mhs1, "dan", nama_mhs2, "adalah mahasiswa fakultas fti")
# Out:
# Asep dan Budi adalah mahasiswa fakultas fti
